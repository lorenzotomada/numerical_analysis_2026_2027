# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## For any issues, question, perplexities, please reach out to me!
# - E-mail: `ltomada@sissa.it`
# - Office: A-701 (7th floor, SISSA)
#
# This notebook is meant as an introduction to Python for beginners.
# People who are not familiar with this programming languages are encouraged to get their hands dirty and tackle the exercises at the end of this file.
